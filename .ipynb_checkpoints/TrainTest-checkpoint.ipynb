# %%
import pandas as pd 
from sklearn.preprocessing import StandardScaler

# load dataset 

df = pd.read_csv("house_prices_nepal_500.csv")



print(df)

df.head(15)

df.tail(10)
# Out:
#       id  area_sqft  bedrooms  bathrooms  year_built  garage   location  \
# 0      1     2226.0       4.0        4.0         NaN     1.0  Kathmandu
# 1      2     3264.0       3.0        4.0      1992.0     1.0  Bhaktapur
# 2      3     3882.0       6.0        NaN      1996.0     0.0   Lalitpur
# 3      4     1261.0       5.0        4.0      1997.0     1.0  Kathmandu
# 4      5        NaN       3.0        2.0      2004.0     0.0  Kathmandu
# ..   ...        ...       ...        ...         ...     ...        ...
# 495  496     1738.0       4.0        4.0      1996.0     2.0  Kathmandu
# 496  497     1583.0       2.0        4.0      2004.0     0.0   Lalitpur
# 497  498     3535.0       5.0        4.0      1993.0     0.0   Lalitpur
# 498  499        NaN       6.0        2.0      1998.0     2.0  Bhaktapur
# 499  500     2725.0       6.0        3.0      1999.0     2.0   Lalitpur
#
#         price
# 0    37566009
# 1    32304330
# 2    37117983
# 3    14860961
# 4    15966742
# ...

# %%
#check missing values 

print(df.isnull().sum())
# Out:
# id             0
# area_sqft     37
# bedrooms      15
# bathrooms     18
# year_built    17
# garage        24
# location      11
# price          0
# dtype: int64

# %%
df['area_sqft'].fillna(df['area_sqft'].median(), inplace = True)

print(df.isnull().sum())
# Out:
# id             0
# area_sqft      0
# bedrooms      15
# bathrooms     18
# year_built    17
# garage        24
# location      11
# price          0
# dtype: int64

# %%
df.head(50)
# Out:
#     id  area_sqft  bedrooms  bathrooms  year_built  garage   location  \
# 0    1     2226.0       4.0        4.0         NaN     1.0  Kathmandu
# 1    2     3264.0       3.0        4.0      1992.0     1.0  Bhaktapur
# 2    3     3882.0       6.0        NaN      1996.0     0.0   Lalitpur
# 3    4     1261.0       5.0        4.0      1997.0     1.0  Kathmandu
# 4    5     2479.0       3.0        2.0      2004.0     0.0  Kathmandu
# 5    6     3296.0       6.0        4.0      2007.0     1.0  Kathmandu
# 6    7     2479.0       4.0        3.0      2006.0     1.0  Bhaktapur
# 7    8      817.0       2.0        2.0      2003.0     1.0  Bhaktapur
# 8    9     3193.0       1.0        4.0      2016.0     NaN   Lalitpur
# 9   10     3726.0       3.0        3.0      2013.0     1.0  Bhaktapur
# 10  11     1932.0       1.0        2.0      2022.0     2.0  Bhaktapur
# 11  12     1633.0       5.0        3.0      1996.0     2.0  Kathmandu
# ...
